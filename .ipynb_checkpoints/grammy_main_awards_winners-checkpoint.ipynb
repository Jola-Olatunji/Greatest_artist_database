# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %%
url = 'https://www.britannica.com/art/Grammy-Award'
response = requests.get(url)

# %%
# save the HTML to file
with open ('Grammy-Award.html', mode = 'wb') as file:
    file.write(response.content)

# %%
# work with html in memory
soup = BeautifulSoup(response.content, 'html.parser')

# %%
table_dict = {'year':[], 'record of the year':[], 'song of the year':[], 'album of the year':[], 'best new artist': []}
keys=['year', 'record of the year', 'song of the year', 'album of the year', 'best new artist']

for a in range(len(soup.table.find_all('tr'))):
    # narrow down on elements in each row of the table
    tr = soup.table.find_all('tr')[a]
    

    for i in range(len(tr.find_all('td'))):
        # narrow down on element in each column
        content = tr.find_all('td')[i].text
        
        # remove non-alphanumeric characters
        cleaned_string = re.sub('\W+',' ',content).strip()
        
        #append into the dictionary
        table_dict[keys[i]].append(cleaned_string)

# %%
table_dict['year'] = table_dict['year'][3:]

# %%
table_df = pd.DataFrame.from_dict(table_dict)

# %%
table_df
# Out:
#     year                              record of the year  \
# 0   1958  Nel blu dipinto di blu Volaré Domenico Modugno
# 1   1959                      Mack the Knife Bobby Darin
# 2   1960       The Theme from A Summer Place Percy Faith
# 3   1961                        Moon River Henry Mancini
# 4   1962   I Left My Heart in San Francisco Tony Bennett
# ..   ...                                             ...
# 60  2018                This Is America Childish Gambino
# 61  2019                           Bad Guy Billie Eilish
# 62  2020               Everything I Wanted Billie Eilish
# 63  2021                  Leave the Door Open Silk Sonic
# 64  2022                           About Damn Time Lizzo
#
#                                   song of the year  \
# 0   Nel blu dipinto di blu Volaré Domenico Modugno
# 1        The Battle of New Orleans Jimmy Driftwood
# 2                    Theme from Exodus Ernest Gold
# 3                         Moon River Henry Mancini
# 4                           What Kind of Fool Am I
# ..                                             ...
# 60                This Is America Childish Gambino
# 61                           Bad Guy Billie Eilish
# 62                           I Can t Breathe H E R
# 63                  Leave the Door Open Silk Sonic
# 64                     Just Like That Bonnie Raitt
#
#                                     album of the year      best new artist
# 0             The Music from Peter Gunn Henry Mancini          not awarded
# 1                    Come Dance with Me Frank Sinatra          Bobby Darin
# 2     The Button Down Mind of Bob Newhart Bob Newhart          Bob Newhart
# 3                  Judy at Carnegie Hall Judy Garland           Peter Nero
# 4                      The First Family Vaughn Meader        Robert Goulet
# ..                                                ...                  ...
# 60                        Golden Hour Kacey Musgraves             Dua Lipa
# 61  When We All Fall Asleep Where Do We Go Billie ...        Billie Eilish
# 62                              Folklore Taylor Swift  Megan Thee Stallion
# 63                                 We Are Jon Batiste       Olivia Rodrigo
# 64                         Harry s House Harry Styles           Samara Joy
#
# [65 rows x 5 columns]
